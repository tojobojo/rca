# %%
# !pip install python-dotenv>=1.0.0
dbutils.library.restartPython()

# %%
dbutils.library.restartPython()

# %%
from rca.analyzer import RCAAnalyzer

run_id = "run_027"
pipeline_name = "merchant_peer_grouping_pipeline"

analyzer = RCAAnalyzer()

result = analyzer.analyze_run(
    run_id=run_id,
    pipeline_name=pipeline_name,
)
print(result)

# %%
# %sql
GRANT USE SCHEMA ON SCHEMA dq_poc TO `438152e9-ee3a-458f-a6be-77a33256755a`;
GRANT SELECT, MODIFY ON TABLE dq_poc.pipeline_run_metrics TO `438152e9-ee3a-458f-a6be-77a33256755a`;
GRANT SELECT, MODIFY ON TABLE dq_poc.pipeline_rule_definitions TO `438152e9-ee3a-458f-a6be-77a33256755a`;
GRANT SELECT, MODIFY ON TABLE dq_poc.pipeline_rule_changes TO `438152e9-ee3a-458f-a6be-77a33256755a`;
GRANT SELECT, MODIFY ON TABLE dq_poc.pipeline_rca_reports TO `438152e9-ee3a-458f-a6be-77a33256755a`;

# %%
# %sql
GRANT USE SCHEMA ON SCHEMA dq_poc TO `account users`;
GRANT SELECT, MODIFY ON TABLE dq_poc.chat_sessions TO `account users`;

# %%
# %sql
-- SHOW CREATE TABLE dq_poc.pipeline_step_audit;

-- desc dq_poc.pipeline_step_audit;

-- desc dq_poc.pipeline_rule_definitions;

desc dq_poc.pipeline_rule_changes;

# %%
# %sql
select * from dq_poc.pipeline_step_audit;

# %%
# %sql
select * from dq_poc.pipeline_rule_definitions;

# %%
# %sql
select * from dq_poc.pipeline_rule_changes;

# %%
# %sql
update dq_poc.pipeline_rule_changes set old_rule_version_id = 'v_5816fa0ed235'
where old_rule_version_id = 'v_a60a358f4034';

# %%
# %sql
select * from dq_poc.pipeline_run_metrics;

# %%
# %sql
select * from dq_poc.pipeline_rca_reports;
